# %% [markdown]
# # Task 1

# %% [markdown]
# ### Dataset and Preprocessing
# * Input image size: 64×64×3; **resize to 32×32×3** (for consistency with CIFAR-100 for transfer learning)
# * Normalize both training and testing image sets
# * Training set: 100,000 images total (500 images per class); if computationally too costly, use 100–200 images per class
# * Use randomly selected **80% of training samples per class for training** and the remaining 20% for validation
# * Test set: 10,000 images (50 per class) — independent set used only for final evaluation

# %% [markdown]
# ### DCNN Architecture Design and Optimization
# * Use an AI-assistive system to design a novel DCNN architecture (reference architectures: ResNet, DenseNet, FractalNet, etc.)
# * Network parameter optimization methods:
#   * **Global Average Pooling (GAP)** as an alternative to fully connected layers
#   * **1×1 convolutions** as bottleneck layers instead of fully connected layers
# * **Dropout** for regularization
# * **Batch Normalization** for training stability and faster convergence

# %% [markdown]
# **Prompt:** Design a novel deep convolutional neural network architecture for image classification. The input is 32×32×3 and the output should support 200 classes (Tiny ImageNet-200). Reference architectures include ResNet, DenseNet, and FractalNet. Incorporate global average pooling (GAP), 1×1 convolutions as bottleneck layers, batch normalization, and dropout. Favor parameter efficiency without sacrificing representational capacity.
#
# **Response:** [AI-generated architecture design to be inserted here]

# %% [markdown]
# ### Activation Functions
# Report model performance using the following activation functions:
# * **ReLU** — standard rectified linear unit (baseline)
# * **GELU** — Gaussian error linear unit
# * **RSwish** — custom rational activation function developed in Assignment 1, Task 2

# %% [markdown]
# ### Model Optimization
# Train the model using the following optimization method:
# * **AdamW** (Adam with Decoupled Weight Decay) optimizer

# %% [markdown]
# ### Training Analysis
# Plot training and validation loss curves to demonstrate learning behavior and convergence during training for fine-tuning the model.

# %% [markdown]
# ### Transfer Learning to CIFAR-100
# * Train and evaluate the novel DCNN on CIFAR-100 using **randomly initialized weights** (He initialization)
# * Select the best-performing model configuration, then initialize it with **pretrained weights from Tiny ImageNet-200** and fine-tune on CIFAR-100
# * Compare performance: random initialization vs. transfer-learned initialization

# %% [markdown]
# ### Model Evaluation
# Evaluate the trained model on the CIFAR-100 test dataset using the following performance metrics:
# * Accuracy
# * Precision
# * Recall
# * F1-score
# * Confusion matrix
# * ROC curve
# * Precision–Recall curve
#
# Present the overall performance of the model without applying any thresholding.
# Additionally, compute and report performance metrics for predictions with confidence scores greater than **0.9**, treating this value as an industrial-level decision threshold.

# %% [markdown]
# ### Results Analysis
