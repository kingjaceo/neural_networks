# %% [markdown]
# # Task 2

# %% [markdown]
# ### Data Preprocessing
# * Dataset: **CIFAR-100** (100 classes, 32×32×3); loaded via `torchvision.datasets.CIFAR100`
# * Normalize both training and testing image sets

# %% [markdown]
# ### Ensemble Method
# Perform an empirical evaluation to select the **best-performing model from Task 1**, then build an ensemble using an **odd number of instances (3)** of that model trained independently (e.g., with different random seeds) on CIFAR-100.
#
# * Load and evaluate all Task 1 model configurations on CIFAR-100 to identify the best performer
# * Train **3 independent instances** of the best model (varied by random seed) on CIFAR-100
# * Combine predictions via **soft voting** (average of class probability distributions) across the 3 instances
# * Re-evaluate the ensemble on the CIFAR-100 test set

# %% [markdown]
# ### Training Analysis
# Plot training and validation loss curves for each of the 3 ensemble members to demonstrate learning behavior and convergence during training.

# %% [markdown]
# ### Model Evaluation
# Evaluate the ensemble on the CIFAR-100 test dataset using the following performance metrics:
# * Accuracy
# * Precision
# * Recall
# * F1-score
# * Confusion matrix
# * ROC curve
# * Precision–Recall curve
#
# Present the overall performance of the model without applying any thresholding.
# Additionally, compute and report performance metrics for predictions with confidence scores greater than **0.9**, treating this value as an industrial-level decision threshold.

# %% [markdown]
# ### Comparative Analysis
# Compare and report results across all three experimental conditions on CIFAR-100:
# 1. **Without transfer learning** — best Task 1 model trained from scratch (random / He initialization)
# 2. **With transfer learning** — best Task 1 model fine-tuned from Tiny ImageNet-200 pretrained weights
# 3. **Ensemble** — 3-model ensemble of the best Task 1 model
#
# Discuss the performance gains at each stage and analyze the contribution of transfer learning and ensembling to overall accuracy and robustness.

# %% [markdown]
# ### Results Analysis
